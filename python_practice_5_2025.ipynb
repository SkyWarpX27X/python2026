# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
  def __init__(self, age, material, floors=1):
    self.age = age
    self.material = material
    self.floors = floors
  def get_info(self):
    return f'{self.age=}, {self.material=}, {self.floors=}'
  def build_floors(self, amount):
    self.floor += amount

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
building1 = Building(70, 'brick')
building2 = Building(10, 'concrete', 12)
print(building1.material)
print(building2.get_info())
# Out:
# brick
# self.age=10, self.material='concrete', self.floors=12

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Example:
  def __init__(self):
    self.public = 'public'
    self._protected = 'protected'
    self.__private = 'private'
example = Example()
print(example.public)
print(example._protected)
#print(example.__private)
# Out:
# public
# protected

# %% [markdown]
# Для public і protected атрибутів значення можливо отримати, при спробі отримати private виникає AttributeError.

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self це посилання на той об'єкт класу, який викликав метод. __init __ використовується переважно для інііалізації атрибутів при створенні об'єкту.

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Shape3D:
  def get_volume(self):
    return 0
  def __add__(self, other):
    return self.get_volume() + other.get_volume()

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
import math

class Cylinder(Shape3D):
  def __init__(self, radius, height):
    self.radius = radius
    self.height = height
  def get_volume(self):
    return math.pi * (self.radius ** 2) * self.height
class Cube(Shape3D):
  def __init__(self, side):
    self.side = side
  def get_volume(self):
    return self.side ** 3

cylinder = Cylinder(5, 10)
cube = Cube(10)

print(cylinder + cube)
# Out:
# 1785.3981633974483

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(isinstance(cylinder, Shape3D), isinstance(cylinder, Cylinder), isinstance(cylinder, Cube))
print(issubclass(Cube, Shape3D), issubclass(Cube, Cube), issubclass(Cube, Cylinder))
# Out:
# True True False
# True True False

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
  def __init__(self, id, balance=0):
    self.__id = id
    self.__balance = balance
  @property
  def balance(self):
    return self.__balance
  @balance.setter
  def balance(self, value):
    if value < 0:
      raise ValueError('Not enough money on balance')
    self.__balance = value
  def top_up(self, amount):
    self.balance += amount
  def withdraw(self, amount):
    self.balance -= amount
wallet = EWallet(1234)
wallet.top_up(500)
wallet.withdraw(400)
print(wallet.balance)
# Out:
# 100

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
  def __init__(self, name, price):
    self.name = name
    self.price = price
class ShoppingCart:
  def __init__(self):
    self.__items = []
  def add(self, item):
    self.__items.append(item)
  def remove(self, item):
    self.__items.remove(item)
  def show(self):
    for item in self.__items:
      print(item.name, item.price)
item1 = Item('Zhyvchyk', 35)
item2 = Item('Coca-cola', 30)
cart = ShoppingCart()
cart.add(item1)
cart.add(item2)
cart.remove(item2)
cart.show()
# Out:
# Zhyvchyk 35

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:
  def __init__(self, brand, age):
    self.brand = brand
    self.production_age = age
class Engine:
  def __init__(self, petrol_type, size):
    self.petrol_type = petrol_type
    self.size = size
class Car(Vehicle, Engine):
  pass
print(Car.mro())
car = Car('Lanos', 25)
# Out:
# [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
numbers = '1234'
iterator = iter(numbers)
for i in range(4):
  print(next(iterator))
next(iterator)
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-946726920.py in <cell line: 0>()
#       3 for i in range(4):
#       4   print(next(iterator))
# ----> 5 next(iterator)
#
# StopIteration:

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
print(next(numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3161884429.py in <cell line: 0>()
# ----> 1 print(next(numbers))
#
# TypeError: 'str' object is not an iterator

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Ітерабельні об'єкти повертають ітератор, а ітератор вже проходить по їхнім значенням.

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class Weekdays:
  def __iter__(self):
    yield 'Monday'
    yield 'Tuesday'
    yield 'Wednesday'
    yield 'Thursday'
    yield 'Friday'
    yield 'Saturday'
    yield 'Sunday'

weekday = iter(Weekdays())
for i in range(7):
  print(next(weekday))
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
